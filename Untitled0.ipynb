# %% [markdown]
# <a href="https://colab.research.google.com/github/charu11/Assignment-DS/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import nltk
nltk.download('stopwords')
nltk.download('wordnet')
# !pip install emot
# !pip install --upgrade scikit-learn

# %% [markdown]
# ### Import the Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import re
from tqdm import tqdm

import string
from nltk.corpus import stopwords
from nltk.stem.wordnet import WordNetLemmatizer
from emot.emo_unicode import UNICODE_EMOJI
from wordcloud import WordCloud
import sklearn
from sklearn import preprocessing
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.layers import Dense, Embedding, Bidirectional, LSTM, Dropout
from tensorflow.keras.callbacks import Callback, EarlyStopping, ModelCheckpoint
from tensorflow.keras import regularizers
from tensorflow.keras.models import Sequential
from tensorflow.keras.utils import to_categorical

pd.set_option('display.max_columns', 38)

# %% [markdown]
# ### Import the data

# %%
df = pd.read_csv('/content/drive/MyDrive/Pickme Assignment/dataset_usecase2.csv', index_col=[0])
df.head()
# Out:
#                   itemname       tag
# 0          Biscuit Pudding  Desserts
# 14     Jelly Yoghurt 425ml  Desserts
# 16  (3) Jelly Yoghurt 80ml  Desserts
# 17        Watalappam 425ml  Desserts
# 19     Two Chocolate Balls  Desserts

# %%
# checkt the length of the dataset
len(df)
# Out:
# 15782

# %%
# check for any null values

df.isnull().sum()
# Out:
# itemname    0
# tag         0
# dtype: int64

# %%
# check unique values of the label
print(df['tag'].unique())
print(f'number of unique labels are: {len(df.tag.unique())}')
# Out:
# ['Desserts' 'Cakes' 'Rice' 'Noodles' 'Roti' 'Bread' 'Short eats'
#  'Biriyani' 'Kottu' 'Pasta' 'Bites' 'Curry' 'Condiments' 'Tea' 'Coffee'
#  'Soft Drinks' 'Fruit Juice' 'Shakes' 'Sushi' 'Stir Fry' 'Salad' 'Soup'
#  'Fast Food' 'Seafood' 'Pizza' 'Dosa' 'Street Food' 'Burger' 'Submarine'
#  'Wrap' 'BBQ' 'Waffles' 'Indian Sweets' 'Shawarma' 'Shellfish' 'Ice Cream'
#  'Sandwiches' 'Bubble Tea']
# number of unique labels are: 38

# %%
# check is there are any non english charactors
# here isascii function is used to identify the non english charactors.
def isEnglish(s):
  return s.isascii()

result = [print('There are non english charactors') for word in df['itemname'] if isEnglish(word)==False]
# Out:
# There are non english charactors
# There are non english charactors
# There are non english charactors
# There are non english charactors
# There are non english charactors
# There are non english charactors
# There are non english charactors
# There are non english charactors
# There are non english charactors
# There are non english charactors
# There are non english charactors
# There are non english charactors
# There are non english charactors
# There are non english charactors
# There are non english charactors
# There are non english charactors
# There are non english charactors
# There are non english charactors
# There are non english charactors
# There are non english charactors
# There are non english charactors
# There are non english charactors
# There are non english charactors
# There are non english charactors
# There are non english charactors

# %% [markdown]
# ##### We've come to a conclusion that there are non english charactors in the data set. so let's remove those non english charactors from the dataset.

# %% [markdown]
# ### Preprocesing

# %%
# remove the numbers inside paramtheisis

def paranthesis(text):
  text =  re.sub(r"\([0-9]+\)", "", text)
  return text
df['itemname'] = df['itemname'].apply(paranthesis)

df
# Out:
#                    itemname         tag
# 0           Biscuit Pudding    Desserts
# 14      Jelly Yoghurt 425ml    Desserts
# 16       Jelly Yoghurt 80ml    Desserts
# 17         Watalappam 425ml    Desserts
# 19      Two Chocolate Balls    Desserts
# ...                     ...         ...
# 171622        Devilled Beef       Curry
# 171624       Beef Mix Curry       Curry
# 171643        Chicken Rolls  Short eats
# 171658        Ice Nestomolt      Shakes
# 171661        Roast Chicken       Bites
#
# [15782 rows x 2 columns]

# %%
# Stop words removal

stop_words = set(stopwords.words('english'))
def remove_stopwords(text):
    return " ".join([word for word in str(text).split() if word not in stop_words])
df['itemname'] = df['itemname'].apply(remove_stopwords)

df
# Out:
#                    itemname         tag
# 0           Biscuit Pudding    Desserts
# 14      Jelly Yoghurt 425ml    Desserts
# 16       Jelly Yoghurt 80ml    Desserts
# 17         Watalappam 425ml    Desserts
# 19      Two Chocolate Balls    Desserts
# ...                     ...         ...
# 171622        Devilled Beef       Curry
# 171624       Beef Mix Curry       Curry
# 171643        Chicken Rolls  Short eats
# 171658        Ice Nestomolt      Shakes
# 171661        Roast Chicken       Bites
#
# [15782 rows x 2 columns]

# %%
#removing unicode charactors
def remove_unicode_chars(text):
    text = text.encode("ascii", "ignore").decode()
    return text
df['itemname'] = df['itemname'].apply(remove_unicode_chars)

df
# Out:
#                    itemname         tag
# 0           Biscuit Pudding    Desserts
# 14      Jelly Yoghurt 425ml    Desserts
# 16       Jelly Yoghurt 80ml    Desserts
# 17         Watalappam 425ml    Desserts
# 19      Two Chocolate Balls    Desserts
# ...                     ...         ...
# 171622        Devilled Beef       Curry
# 171624       Beef Mix Curry       Curry
# 171643        Chicken Rolls  Short eats
# 171658        Ice Nestomolt      Shakes
# 171661        Roast Chicken       Bites
#
# [15782 rows x 2 columns]

# %%
#removing punctuations

# string.punctuation
def remove_punctuations(text):
    text = re.sub('[%s]' % re.escape(string.punctuation), " ",text)
    return text
df['itemname'] = df['itemname'].apply(remove_punctuations)
df
# Out:
#                    itemname         tag
# 0           Biscuit Pudding    Desserts
# 14      Jelly Yoghurt 425ml    Desserts
# 16       Jelly Yoghurt 80ml    Desserts
# 17         Watalappam 425ml    Desserts
# 19      Two Chocolate Balls    Desserts
# ...                     ...         ...
# 171622        Devilled Beef       Curry
# 171624       Beef Mix Curry       Curry
# 171643        Chicken Rolls  Short eats
# 171658        Ice Nestomolt      Shakes
# 171661        Roast Chicken       Bites
#
# [15782 rows x 2 columns]

# %%
#converting emojis
def convert_emojis(text):
    for emot in UNICODE_EMOJI:
        text = text.replace(emot, "_".join(UNICODE_EMOJI[emot].replace(",","").replace(":","").split()))
    return text
df['itemname'] = df['itemname'].apply(convert_emojis)
df
# Out:
#                    itemname         tag
# 0           Biscuit Pudding    Desserts
# 14      Jelly Yoghurt 425ml    Desserts
# 16       Jelly Yoghurt 80ml    Desserts
# 17         Watalappam 425ml    Desserts
# 19      Two Chocolate Balls    Desserts
# ...                     ...         ...
# 171622        Devilled Beef       Curry
# 171624       Beef Mix Curry       Curry
# 171643        Chicken Rolls  Short eats
# 171658        Ice Nestomolt      Shakes
# 171661        Roast Chicken       Bites
#
# [15782 rows x 2 columns]

# %%
#removing extra spaces
def remove_extra_spaces(text):
    text = re.sub(' +', ' ', text).strip()
    return text
df['itemname'] = df['itemname'].apply(remove_extra_spaces)

df
# Out:
#                    itemname         tag
# 0           Biscuit Pudding    Desserts
# 14      Jelly Yoghurt 425ml    Desserts
# 16       Jelly Yoghurt 80ml    Desserts
# 17         Watalappam 425ml    Desserts
# 19      Two Chocolate Balls    Desserts
# ...                     ...         ...
# 171622        Devilled Beef       Curry
# 171624       Beef Mix Curry       Curry
# 171643        Chicken Rolls  Short eats
# 171658        Ice Nestomolt      Shakes
# 171661        Roast Chicken       Bites
#
# [15782 rows x 2 columns]

# %%
# converting capital letters to simple letters

df['itemname'] = df['itemname'].str.lower()
df
# Out:
#                    itemname         tag
# 0           biscuit pudding    Desserts
# 14      jelly yoghurt 425ml    Desserts
# 16       jelly yoghurt 80ml    Desserts
# 17         watalappam 425ml    Desserts
# 19      two chocolate balls    Desserts
# ...                     ...         ...
# 171622        devilled beef       Curry
# 171624       beef mix curry       Curry
# 171643        chicken rolls  Short eats
# 171658        ice nestomolt      Shakes
# 171661        roast chicken       Bites
#
# [15782 rows x 2 columns]

# %%
#lemmatization
lemmatizer = WordNetLemmatizer()
def lemmatize_text(text):
    words = [lemmatizer.lemmatize(word) for word in text.split()]
    text = ' '.join(words)
    return text
df['itemname'] = df['itemname'].apply(lemmatize_text)

df
# Out:
#                    itemname         tag
# 0           biscuit pudding    Desserts
# 14      jelly yoghurt 425ml    Desserts
# 16       jelly yoghurt 80ml    Desserts
# 17         watalappam 425ml    Desserts
# 19       two chocolate ball    Desserts
# ...                     ...         ...
# 171622        devilled beef       Curry
# 171624       beef mix curry       Curry
# 171643         chicken roll  Short eats
# 171658        ice nestomolt      Shakes
# 171661        roast chicken       Bites
#
# [15782 rows x 2 columns]

# %% [markdown]
# ### Exploratory Data Analysis

# %%
data = df['tag'].value_counts()
label = df['tag'].value_counts().keys()

fig = plt.figure(figsize =(10, 10))
plt.pie(data, labels = label, autopct="%1.1f%%", colors=sns.color_palette("Set3"))



# show plot
plt.show()

# %%
plt.figure(figsize=(9,5))
sns.countplot(x='tag',  data=df, palette="Set3")
plt.xticks(ticks=np.arange(38), labels=df['tag'].unique(),rotation = 90)
plt.title(f"Label Distribution")

plt.tight_layout()

# %%
# word level analysis

# to analyse the words, we need all the text as a one text document

text = ' '.join(word for word in df['itemname'])
text_doc = text.split()

# %%
# create the dictionary contains the word and the count as the key and value

word_count = {}

for word in set(text_doc):
    word_count[word]= text_doc.count(word)
#Creating dataframe of words
df_word= pd.DataFrame(word_count.items(),columns=['word','count'])

# %%
# add the word length to the dataframe
df_word['word_len']= df_word['word'].map(lambda x: len(x))

# rank the word count by descending order
df_word=df_word.sort_values('count',ascending=False).reset_index(drop=True)

# %%
# lets calculate top 20 most used words
df_top= df_word.head(20)
sns.barplot(x=df_top['count'], y=df_top['word'])
# Out:
# <Axes: xlabel='count', ylabel='word'>

# %%
# plot the length distribution
df_word['word_len'].hist()
# Out:
# <Axes: >

# %%
#word cloud
wordcloud = WordCloud(background_color='white',max_words=100,
                      max_font_size=40,
                      scale=3,
                      random_state=1).generate(text)
plt.axis('off')
plt.imshow(wordcloud)

# %%
## lets analyze most used words in top 3 labels
df1 = df.groupby(['tag']).count()
df1 = df1.reset_index()
df1=df1.sort_values('itemname',ascending=False).reset_index(drop=True)
df1.head()

# %%
tag_list = df1['tag'][:5]

# %%
tag_list
# Out:
# 0        Rice
# 1    Stir Fry
# 2       Kottu
# 3       Curry
# 4    Desserts
# Name: tag, dtype: object

# %%
def tag_word_cloud(number): # number should be from 0 to 2
  words = ' '.join(i for i in df[df['tag'] == tag_list[number]]['itemname'])
  wordcloud = WordCloud(background_color='white',max_words=100,
                      max_font_size=40,
                      scale=3,
                      random_state=1).generate(words)
  plt.axis('off')
  plt.imshow(wordcloud)

# %%
tag_word_cloud(0) ### this is the word cloud for the rice
# Out:
# %%
tag_word_cloud(3) # this is for the curry

# %%
tag_word_cloud(4) # this is for the desserts

# %% [markdown]
# ### Feature Engineering

# %%
# tokenizing the data
token = Tokenizer()
token.fit_on_texts(df['itemname'])

# %%
seq = token.texts_to_sequences(df['itemname'])

# %%
# pad the sentences

max_length = 50
pad_seq = pad_sequences(seq, maxlen=max_length, padding='post')

# %%
embedding_vector = {}
vocab_size = len(token.word_index) +1

f = open('/content/drive/MyDrive/Pickme Assignment/glove.6B.50d.txt')

for line in tqdm(f):
  value = line.split(' ')
  word = value[0]
  coef = np.array(value[1:], dtype = 'float32')
  embedding_vector[word] = coef
# Out:
# 400000it [00:09, 40275.10it/s]

# %%
#create a weight matrix for words in data

embedding_matrix = np.zeros((vocab_size, 50))
for word,i in tqdm(token.word_index.items()):
    embedding_value = embedding_vector.get(word)
    if embedding_value is not None:
        embedding_matrix[i] = embedding_value
# Out:
# 100%|██████████| 3294/3294 [00:00<00:00, 187567.54it/s]

# %%
#encode the label
label_encoder = preprocessing.LabelEncoder()
df['tag']= label_encoder.fit_transform(df['tag'])
y = to_categorical(df['tag'])

# %%
df['tag'].unique()
# Out:
# array([10,  6, 20, 17, 21,  3, 28,  1, 16, 18,  2,  9,  8, 35,  7, 29, 13,
#        25, 34, 31, 22, 30, 12, 24, 19, 11, 32,  5, 33, 37,  0, 36, 15, 26,
#        27, 14, 23,  4])

# %%
X_train, X_test, y_train, y_test = train_test_split( pad_seq, y, test_size=0.33, random_state=100)

# %%
df.head()
# Out:
#                itemname       tag
# 0       biscuit pudding  Desserts
# 14  jelly yoghurt 425ml  Desserts
# 16   jelly yoghurt 80ml  Desserts
# 17     watalappam 425ml  Desserts
# 19   two chocolate ball  Desserts

# %%
df.head()
# Out:
#                itemname       tag
# 0       biscuit pudding  Desserts
# 14  jelly yoghurt 425ml  Desserts
# 16   jelly yoghurt 80ml  Desserts
# 17     watalappam 425ml  Desserts
# 19   two chocolate ball  Desserts

# %%
y
# Out:
# Rice             2238
# Stir Fry         1293
# Kottu            1174
# Curry             907
# Desserts          833
# Bites             702
# Short eats        699
# Noodles           691
# Roti              638
# Pasta             521
# Shakes            495
# Cakes             489
# Burger            481
# Fruit Juice       430
# Soup              370
# Pizza             326
# Sandwiches        284
# Bread             279
# Biriyani          268
# Salad             265
# Submarine         260
# Coffee            213
# Dosa              204
# Soft Drinks       197
# Indian Sweets     189
# Wrap              170
# Seafood           153
# Ice Cream         153
# Fast Food         143
# Tea               138
# Condiments        135
# Sushi             115
# Waffles           100
# Shawarma           69
# Street Food        64
# BBQ                52
# Bubble Tea         25
# Shellfish          19
# Name: tag, dtype: int64

# %%
embedding_matrix.shape
# Out:
# (3295, 50)

# %% [markdown]
# ### Modeling

# %%
model = Sequential()
model.add(Embedding(vocab_size,50, weights = [embedding_matrix], input_length=max_length, trainable=True))
model.add(Bidirectional(LSTM(25, dropout=0.1)))
model.add(Dense(25, activation='relu',kernel_regularizer=regularizers.l2(0.01)))
model.add(Dropout(0.1))
model.add(Dense(12, activation='relu',kernel_regularizer=regularizers.l2(0.01)))
model.add(Dropout(0.1))
model.add(Dense(38,activation = 'softmax'))
model.summary()

reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(monitor="val_loss", factor=0.3,
                                                 patience=2, verbose=1, min_lr=1e-7)
optimizer = tf.keras.optimizers.Adam(learning_rate=0.001)

model.compile(
    optimizer = optimizer,
    loss = tf.keras.losses.CategoricalCrossentropy(from_logits=True),
    #metrics = [tf.keras.metrics.Accuracy(), tf.keras.metrics.Precision(), tf.keras.metrics.Recall()]
    metrics = [tf.keras.metrics.BinaryAccuracy(name='accuracy')]
)



history = model.fit(
    X_train, y_train,
    batch_size = 32,
    epochs = 10,
    validation_split = 0.3,

    callbacks = [reduce_lr]
)
# Out:
# Model: "sequential_11"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_11 (Embedding)    (None, 50, 50)            164750
#
#  bidirectional_11 (Bidirecti  (None, 50)               15200
#  onal)
#
#  dense_33 (Dense)            (None, 25)                1275
#
#  dropout_22 (Dropout)        (None, 25)                0
#
#  dense_34 (Dense)            (None, 12)                312
#
#  dropout_23 (Dropout)        (None, 12)                0
#
#  dense_35 (Dense)            (None, 38)                494
#
# =================================================================
# Total params: 182,031
# Trainable params: 182,031
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# /usr/local/lib/python3.10/dist-packages/keras/backend.py:5561: UserWarning: "`categorical_crossentropy` received `from_logits=True`, but the `output` argument was produced by a Softmax activation and thus does not represent logits. Was this intended?
#   output, from_logits = _get_logits(
# 232/232 [==============================] - 21s 67ms/step - loss: 3.4485 - accuracy: 0.9743 - val_loss: 3.0159 - val_accuracy: 0.9758 - lr: 0.0010
# Epoch 2/10
# 232/232 [==============================] - 15s 63ms/step - loss: 2.7250 - accuracy: 0.9761 - val_loss: 2.4557 - val_accuracy: 0.9767 - lr: 0.0010
# Epoch 3/10
# 232/232 [==============================] - 15s 63ms/step - loss: 2.3311 - accuracy: 0.9773 - val_loss: 2.1882 - val_accuracy: 0.9779 - lr: 0.0010
# Epoch 4/10
# 232/232 [==============================] - 15s 63ms/step - loss: 2.1174 - accuracy: 0.9781 - val_loss: 2.0098 - val_accuracy: 0.9786 - lr: 0.0010
# Epoch 5/10
# 232/232 [==============================] - 17s 73ms/step - loss: 1.9339 - accuracy: 0.9790 - val_loss: 1.8427 - val_accuracy: 0.9798 - lr: 0.0010
# Epoch 6/10
# 232/232 [==============================] - 15s 63ms/step - loss: 1.8092 - accuracy: 0.9801 - val_loss: 1.7430 - val_accuracy: 0.9806 - lr: 0.0010
# Epoch 7/10
# 232/232 [==============================] - 15s 63ms/step - loss: 1.7057 - accuracy: 0.9809 - val_loss: 1.6836 - val_accuracy: 0.9814 - lr: 0.0010
# Epoch 8/10
# 232/232 [==============================] - 14s 62ms/step - loss: 1.5997 - accuracy: 0.9822 - val_loss: 1.5820 - val_accuracy: 0.9833 - lr: 0.0010
# Epoch 9/10
# 232/232 [==============================] - 14s 62ms/step - loss: 1.5322 - accuracy: 0.9830 - val_loss: 1.5317 - val_accuracy: 0.9845 - lr: 0.0010
# Epoch 10/10
# 232/232 [==============================] - 14s 59ms/step - loss: 1.4791 - accuracy: 0.9839 - val_loss: 1.4949 - val_accuracy: 0.9847 - lr: 0.0010

# %%
# get the predictions
y_pred = model.predict(X_test)
# Out:
# 163/163 [==============================] - 3s 13ms/step

# %%
# get the position for highest probability
y_pred = np.argmax(y_pred, axis=1)

# %%
labels =df['tag'].unique()

# %%
y_test = np.argmax(y_test, axis=1)

# %%
y_test
# Out:
# array([18, 16,  1, ..., 17,  9, 25])

# %%
confusion_matrix = confusion_matrix(y_test, y_pred, labels=labels)

# %%
print(confusion_matrix)

# %% [markdown]
# ####Conclusion
# Due to the lack of amoount of data, it's bit hard predict the classes with less amount of data.
# further hyper parameters can be used to improve the accuracy. hyper parameters optimization has not considered here.
